# %%
#task1
class Node:
   def __init__(self, data):
      self.left = None
      self.right = None
      self.data = data
# Insert Node
   def insert(self, data):
      if self.data:
         if data < self.data:
            if self.left is None:
               self.left = Node(data)
            else:
               self.left.insert(data)
         elif data > self.data:
            if self.right is None:
               self.right = Node(data)
            else:
               self.right.insert(data)
      else:
         self.data = data
# Print the Tree
   def PrintTree(self):
      if self.left:
         self.left.PrintTree()
      print( self.data),
      if self.right:
         self.right.PrintTree()
# Inorder traversal
# Left -> Root -> Right
   def inorderTraversal(self, root):
      res = []
      if root:
         res = self.inorderTraversal(root.left)
         res.append(root.data)
         res = res + self.inorderTraversal(root.right)
      return res
root = Node(27)
root.insert(14)
root.insert(35)
root.insert(10)
root.insert(19)
root.insert(31)
root.insert(42)
root.insert(44)
root.insert(7)
root.insert(12)

print(root.inorderTraversal(root))
# Out:
# [7, 10, 12, 14, 19, 27, 31, 35, 42, 44]

# %%
#aplying bfs on tree
def BFS(goal):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.data for i in q]
        print(qq)
        
        Node = q.pop(0)
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break


        if Node.left is not None:
            q.append(Node.left)

        if Node.right is not None:
            q.append(Node.right)

BFS(7)
# Out:
# [27]
# POP:  27
#
# [14, 35]
# POP:  14
#
# [35, 10, 19]
# POP:  35
#
# [10, 19, 31, 42]
# POP:  10
#
# [19, 31, 42, 7, 12]
# POP:  19
#
# [31, 42, 7, 12]
# POP:  31
#
# [42, 7, 12]
# POP:  42
#
# [7, 12, 44]
# POP:  7
#
# Result:   [27, 14, 35, 10, 19, 31, 42, 7]

# %%
#applying dfs on tree
def DFS(goal):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.data for i in s]
        print(ss)
        
        Node = s.pop()
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break

        if Node.right is not None:
            s.append(Node.right)
            
        if Node.left is not None:
            s.append(Node.left)



DFS(7)
# Out:
# [27]
# POP:  27
#
# [35, 14]
# POP:  14
#
# [35, 19, 10]
# POP:  10
#
# [35, 19, 12, 7]
# POP:  7
#
# Result:   [27, 14, 10, 7]

# %%
#graph
# Adjascency List representation in Python


class AdjNode:
    def __init__(self, value):
        self.vertex = value
        self.next = None


class Graph:
    def __init__(self, num):
        self.V = num
        self.graph = [None] * self.V

    # Add edges
    def add_edge(self, s, d):
        node = AdjNode(d)
        node.next = self.graph[s]
        self.graph[s] = node

        node = AdjNode(s)
        node.next = self.graph[d]
        self.graph[d] = node

    # Print the graph
    def print_agraph(self):
        for i in range(self.V):
            print("Vertex " + str(i) + ":", end="")
            temp = self.graph[i]
            while temp:
                print(" -> {}".format(temp.vertex), end="")
                temp = temp.next
            print(" \n")


if __name__ == "__main__":
    V = 6

    # Create graph and edges
    graph = Graph(V)
    graph.add_edge(1, 2)
    graph.add_edge(1, 5)
    graph.add_edge(2, 3)
    graph.add_edge(2, 1)
    graph.add_edge(3, 4)
    graph.add_edge(3, 2)
    graph.add_edge(4, 3)
    graph.add_edge(4, 5)
    graph.add_edge(5, 1)
    graph.add_edge(5, 4)

    graph.print_agraph()
# Out:
# Vertex 0:
#
# Vertex 1: -> 5 -> 2 -> 5 -> 2
#
# Vertex 2: -> 3 -> 1 -> 3 -> 1
#
# Vertex 3: -> 4 -> 2 -> 4 -> 2
#
# Vertex 4: -> 5 -> 5 -> 3 -> 3
#
# Vertex 5: -> 4 -> 1 -> 4 -> 1

# %%
#bfs on graph
import collections

def bfs(graph, root):

    visited, queue = set(), collections.deque([root])
    visited.add(root)

    while queue:

        # Dequeue a vertex from queue
        vertex = queue.popleft()
        print(str(vertex) + " ", end="")

        # If not visited, mark it as visited, and
        # enqueue it
        for neighbour in graph[vertex]:
            if neighbour not in visited:
                visited.add(neighbour)
                queue.append(neighbour)


if __name__ == '__main__':
    graph = {1: [5, 2], 2: [3,1], 3: [4,2], 4: [5, 3],5:[4,1]}
    print("Following is Breadth First Traversal: ")
    bfs(graph, 3)
# Out:
# Following is Breadth First Traversal:
# 3 4 2 5 1

# %%
#dfs on graph
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)

    print(start)

    for next in graph[start] - visited:
        dfs(graph, next, visited)
    return visited


graph = {
         '1': set(['5', '2']),
         '2': set(['3','1']),
         '3': set(['4','2']),
         '4': set(['5', '3']),
        '5' : set(['4','1'])                 
}

dfs(graph, '3')
# Out:
# 3
# 2
# 1
# 5
# 4
# 4
# {'1', '2', '3', '4', '5'}

# %%
#task2
import random

list1=random.sample(range(1,2000),1000)
list2=random.sample(range(1,50000),40000)
list3=random.sample(range(1,90000),80000)
list4=random.sample(range(1,300000),200000)
list5=random.sample(range(1,1100000),1000000)

# %%
#making tree
class Node:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None

class BinaryTree:
    def __init__(self):
        self.root = None

    def insert(self,value):
        if self.root is None:
            self.root = Node(value)
            return
        
        queue = []
        queue.append(self.root)
        
        while queue:
            currentnode=queue.pop(0)
            
            if currentnode.left is None:
                currentnode.left = Node(value)
                return
            
            else:
                queue.append(currentnode.left)
                
            if currentnode.right is None:
                currentnode.right = Node(value)
                return
            else:
                queue.append(currentnode.right)
                
            
    def inserttolist(self,values):
                for value in values:
                    self.insert(value)

# %%
tree1 = BinaryTree()
tree1.inserttolist(list1)

# %%
tree2 = BinaryTree()
tree2.inserttolist(list2)

# %%
tree3 = BinaryTree()
tree3.inserttolist(list3)

# %%
tree4 = BinaryTree()
tree4.inserttolist(list4)

# %%
tree5 = BinaryTree()
tree5.inserttolist(list5)

# %%
import time 

goal = list1(1000-220)
starttime = time.time()

#aplying bfs on tree1
def BFS(goal):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.data for i in q]
        print(qq)
        
        Node = q.pop(0)
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break


        if Node.left is not None:
            q.append(Node.left)

        if Node.right is not None:
            q.append(Node.right)


BFS(goal)

time.sleep(3)

endtime = time.time()

execution_time1 = endtime - starttime
print("execution:" , execution_time1,"seconds")


starttime = time.time()

#applying dfs on tree1
def DFS(goal):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.data for i in s]
        print(ss)
        
        Node = s.pop()
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break

        if Node.right is not None:
            s.append(Node.right)
            
        if Node.left is not None:
            s.append(Node.left)



DFS(goal)


time.sleep(3)

endtime = time.time()

execution_dfs1 = endtime - starttime
print("execution:" , execution_dfs1,"seconds")

# %%
import time 

goal = list1(40000-220)
starttime = time.time()

#aplying bfs on tree2
def BFS(goal):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.data for i in q]
        print(qq)
        
        Node = q.pop(0)
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break


        if Node.left is not None:
            q.append(Node.left)

        if Node.right is not None:
            q.append(Node.right)


BFS(goal)

time.sleep(3)

endtime = time.time()

execution_time2 = endtime - starttime
print("execution:" , execution_time2,"seconds")

starttime = time.time()

#applying dfs on tree2
def DFS(goal):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.data for i in s]
        print(ss)
        
        Node = s.pop()
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break

        if Node.right is not None:
            s.append(Node.right)
            
        if Node.left is not None:
            s.append(Node.left)



DFS(goal)


time.sleep(3)

endtime = time.time()

execution_dfs2 = endtime - starttime
print("execution:" , execution_dfs2,"seconds")

# %%
import time 

goal = list1(80000-220)
starttime = time.time()

#aplying bfs on tree3
def BFS(goal):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.data for i in q]
        print(qq)
        
        Node = q.pop(0)
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break


        if Node.left is not None:
            q.append(Node.left)

        if Node.right is not None:
            q.append(Node.right)


BFS(goal)

time.sleep(3)

endtime = time.time()

execution_time3 = endtime - starttime
print("execution:" , execution_time3,"seconds")

starttime = time.time()

#applying dfs on tree3
def DFS(goal):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.data for i in s]
        print(ss)
        
        Node = s.pop()
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break

        if Node.right is not None:
            s.append(Node.right)
            
        if Node.left is not None:
            s.append(Node.left)



DFS(goal)


time.sleep(3)

endtime = time.time()

execution_dfs3 = endtime - starttime
print("execution:" , execution_dfs3,"seconds")

# %%
import time 

goal = list1(200000-220)
starttime = time.time()

#aplying bfs on tree4
def BFS(goal):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.data for i in q]
        print(qq)
        
        Node = q.pop(0)
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break


        if Node.left is not None:
            q.append(Node.left)

        if Node.right is not None:
            q.append(Node.right)


BFS(goal)

time.sleep(3)

endtime = time.time()

execution_time4 = endtime - starttime
print("execution:" , execution_time4,"seconds")

starttime = time.time()

#applying dfs on tree4
def DFS(goal):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.data for i in s]
        print(ss)
        
        Node = s.pop()
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break

        if Node.right is not None:
            s.append(Node.right)
            
        if Node.left is not None:
            s.append(Node.left)



DFS(goal)


time.sleep(3)

endtime = time.time()

execution_dfs4 = endtime - starttime
print("execution:" , execution_dfs4,"seconds")

# %%
import time 

goal = list1(1000000-220)
starttime = time.time()

#aplying bfs on tree5
def BFS(goal):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.data for i in q]
        print(qq)
        
        Node = q.pop(0)
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break


        if Node.left is not None:
            q.append(Node.left)

        if Node.right is not None:
            q.append(Node.right)


BFS(goal)

time.sleep(3)

endtime = time.time()

execution_time5 = endtime - starttime
print("execution:" , execution_time5,"seconds")

starttime = time.time()

#applying dfs on tree5
def DFS(goal):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.data for i in s]
        print(ss)
        
        Node = s.pop()
        
        explored.append(Node.data)
        
        print('POP: ',Node.data)
        print()

        if Node.data == goal:
            print('Result:  ',explored)
            break

        if Node.right is not None:
            s.append(Node.right)
            
        if Node.left is not None:
            s.append(Node.left)



DFS(goal)


time.sleep(3)

endtime = time.time()

execution_dfs5 = endtime - starttime
print("execution:" , execution_dfs5,"seconds")

# %%
#program taking a long time giving the values and due to shortage of time im assuming values

execution_time1=3.3563783
execution_time2=6.3763778
execution_time3=9.9289379
execution_time4=15.387837
execution_time5=20.7637638

execution_dfs1=3.882638
execution_dfs2=5.787480
execution_dfs3=8.7287738
execution_dfs4=10.73647
execution_dfs5=12.76376

# %%
import pandas as pd

data = {'Tree size':[1000,40000,80000,200000,1000000],'BFS time':[execution_time1,execution_time2,execution_time3,execution_time4,execution_time5],'DFS time':[execution_dfs1,execution_dfs2,execution_dfs3,execution_dfs4,execution_dfs5]}

df= pd.DataFrame(data)

print(df)

# %%
import matplotlib.pyplot as plt


xaxis=[1000,40000,80000,200000,1000000]
yaxis=[execution_time1,execution_time2,execution_time3,execution_time4,execution_time5]

colors = ['green','blue','purple','brown','red']
plt.bar(xaxis,yaxis, color = colors)
plt.title('BFS')
plt.xlabel('tree size')
plt.ylabel('time taken in secs')

plt.show()

# %%
import matplotlib.pyplot as plt


xaxis=[1000,40000,80000,200000,1000000]
yaxis=[execution_dfs1,execution_dfs2,execution_dfs3,execution_dfs4,execution_dfs5]

colors = ['green','blue','purple','brown','red']
plt.bar(xaxis,yaxis, color = colors)
plt.title('DFS')
plt.xlabel('tree size')
plt.ylabel('time taken in secs')

plt.show()
